# %% [markdown]
# Pruebas para bajar una query de redatam a un dataframe de Pandas

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Consulta para NBI Argentina
# Cantidad de casas que no posee inodoro o letrina HOGAR.H1510 = 2
query_nbi_ii_arg = 'HOGAR.H1510 = 2'


# Consulta para NBI Uruguay

# NBI II criterio agua potable:
#    Un hogar particular tendrá una necesidad básica insatisfecha con relación al abastecimiento de agua potable si esta
#    no llega por cañería dentro de la vivienda o si, en caso de que lo haga, el origen no sea red general ni pozo 
#    surgente protegido.
query_agua_potable_uy = 'HOGAR.H1409 > 3 AND HOGAR.H1308 <> 1'


# NBI II criterio excretas:
#    Un hogar particular tendrá necesidades básicas insatisfechas en saneamiento si cumple al menos una de las
#    siguientes condiciones: 
#        a) no accede a baño;
#        b) accediendo, su uso no es exclusivo del hogar o;
#        c) la evacuación del servicio sanitario no es a red general, fosa séptica o pozo negro.

query_excretas_uy_a = query_nbi_ii_arg
query_excretas_uy_b = 'HOGAR.H1712 = 4 OR HOGAR.H1813 = 2'

# %%
def load_html(path):
    with open(path) as html_doc:
        soup = BeautifulSoup(html_doc, 'html.parser')
        return soup

# %%
f1 = load_html('../datos/query_nbi_ii_arg.html')

# %%
rows = f1.find('table').find_all('tr')
print(len(rows))
# Out:
# 22797

# %%
[int(r.text.replace('AREA # ', '').split('\n')[1]) for r in rows if 'AREA # ' in r.text]
# Out:
# [820070101,
#  820070102,
#  820070103,
#  820070104,
#  820070201,
#  820070202,
#  820070203,
#  820070204,
#  820070205,
#  820070206,
#  820070207,
#  820070208,
#  820070209,
#  820070210,
#  820070211,
#  820070212,
#  820070213,
#  820070214,
#  820070215,
#  820070216,
#  820070217,
#  820070301,
#  820070302,
#  820070303,
#  820070304,
#  820070305,
#  820070306,
#  820070307,
#  820070308,
#  820070309,
#  820070310,
#  820070311,
#  820070312,
#  820070313,
#  820070314,
#  820070315,
#  820070401,
#  820070402,
#  820070403,
#  820070404,
#  820070405,
#  820070406,
#  820070407,
#  820070408,
#  820070409,
#  820070410,
#  820070411,
#  820070412,
#  820070413,
#  820070414,
#  820140101,
#  820140102,
#  820140103,
#  820140104,
#  820140105,
#  820140106,
#  820140107,
#  820140108,
#  820140109,
#  820140110,
#  820140111,
#  820140112,
#  820140113,
#  820140114,
#  820140115,
#  820140116,
#  820140117,
#  820140118,
#  820140119,
#  820140120,
#  820140121,
#  820140122,
#  820140123,
#  820140124,
#  820140125,
#  820140126,
#  820140127,
#  820140128,
#  820140129,
#  820140130,
#  820140201,
#  820140202,
#  820140203,
#  820140204,
#  820140205,
#  820140206,
#  820140207,
#  820140208,
#  820140209,
#  820140210,
#  820140211,
#  820140212,
#  820140213,
#  820140214,
#  820140215,
#  820140216,
#  820140217,
#  820140218,
#  820140219,
#  820140301,
#  820140302,
#  820140303,
#  820140304,
#  820140305,
#  820140306,
#  820140307,
#  820140308,
#  820140309,
#  820140310,
#  820140311,
#  820140312,
#  820140401,
#  820140402,
#  820140403,
#  820140404,
#  820140405,
#  820140406,
#  820140407,
#  820140408,
#  820140409,
#  820140410,
    'MAIN': 'WebServerMain.inl',
    'BASE': 'CPV2010B',
    'CODIGO': 'xxUsuarioxx',
    'ITEM': 'FREQHOG',
    'MODE': 'RUN',
    'TITLE': '',

    'VARIABLE': 'HOGAR.HV01',
    'AREABREAK': 'RADIO',
    'SELECT': 'Sels\Prov82.sel',
    'INLINESELECTION': '',
    'SEL_FILTER': '',
    'FILTER': query_agua_potable_uy,
    'FORMAT': 'HTML',
    'SUBMIT': 'Ejecutar',
}
headers = {
    'Content-Type': 'application/x-www-form-urlencoded'
}
result_requet_1 = requests.get(url, params=params, headers=headers)

# %%
print(result_request_1.text)
# Out:
# <br>
# <html>
#   <head>
#
#     <title>R+SP Display/Output Page</title>
#
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Cache-Control" content="no-cache">
#     <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">
#
#     <script type="text/javascript" src="/redatam/js/jquery-1.9.1.min.js"></script>
#     <script type="text/javascript" src="/redatam/js/ui/jquery-ui-1.10.2.custom.min.js"></script>
#     <script type="text/javascript" src="/redatam/js/jquery.form.js"></script>
#
#     <link rel="stylesheet" type="text/css" href="/redarg/css/themes/redmond/jquery-ui.min.css" />
#     <link rel="stylesheet" type="text/css" href="/redatam/css/red.input.css" />
#     <link rel="stylesheet" type="text/css" href="/redatam/css/panels.css" />
#
#   </head>
#
#   <body >
#     <div  class="ui-panel ui-widget-content ui-corner-all" align="left">
#       <H2>Hogares</H2>
#
#     </div>
#     <table border="0" cellspacing="0" cellpadding="5" width="100%">
#       <tr>
#   	    <td align="center"><H3>Tipo de vivienda</H3><br>
# <iframe src="https://redatam.indec.gob.ar/argbin/WebUtilities.exe/Text?LFN=RpBases\Tempo\~tmp_12863501.htm&amp;TYPE=TMP" frameborder='0' width='100%' height='300' scrolling='auto' name='grid'>Redatam</iframe><br>
# </td>
#       </tr>
#       <tr>
#   	    <td align="center"></td>
#       </tr>
#       <tr>
#   	    <td align="center"></td>
#       </tr>
#     </table>
#     <br/>
#     <div class="ui-panel ui-widget-content ui-corner-all" align="center">
#       WebMaster <a href="mailto:soporteredatam@indec.mecon.gov.ar">soporteredatam@indec.mecon.gov.ar</a><br>© 2002-2014 <img src="/redarg/images/banderita.gif" hspace=2 align="middle">Consultas de información estadística: <a href="mailto:ces@indec.mecon.gov.ar"><b>ces@indec.mecon.gov.ar</b></a><br>Comentarios sobre nuestro sitio: <b><a href="mailto:indecweb@indec.mecon.gov.ar">indecweb@indec.mecon.gov.ar</b></a><br>Página optimizada para MS-Internet Explorer y resolución 800x600<br>INDEC - Av. Julio A. Roca 609, PB, C1067ABB Ciudad Autónoma de Buenos Aires, Argentina.Teléfono: 54 11 4349-9235</nobr><br>Powered by <a href="https://www.redatam.org/" target="_blank">REDATAM®</a>
#     </div>
#   </body>
#
# </html>

# %%
html_1 = BeautifulSoup(result_request_1.text, 'html.parser')

# %%
iframe = html_1.find('iframe')
print(iframe.attrs['src'])
# Out:
# https://redatam.indec.gob.ar/argbin/WebUtilities.exe/Text?LFN=RpBases\Tempo\~tmp_12863501.htm&TYPE=TMP

# %%
def bajar_query(query):
    url_request = 'https://redatam.indec.gob.ar/argbin/RpWebEngine.exe/Frequency'

#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210114 45871',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                6 100,00 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 820210115 45872',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210116 45873',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                8 100,00 100,00',
#  'Total                8 100,00 100,00',
#  '',
#  'AREA # 820210117 45874',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210118 45875',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210119 45876',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               15  93,75  93,75',
#  'Rancho                1   6,25 100,00',
#  'Total               16 100,00 100,00',
#  '',
#  'AREA # 820210120 45877',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                6 100,00 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 820210121 45878',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               16 100,00 100,00',
#  'Total               16 100,00 100,00',
#  '',
#  'AREA # 820210122 45879',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                6 100,00 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 820210123 45880',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210124 45881',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210125 45882',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210126 45883',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                4 100,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 820210127 45884',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 820210128 45885',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210129 45886',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                4 100,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 820210130 45887',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3 100,00 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 820210131 45888',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                4  80,00  80,00',
#  'Vivienda móvil                1  20,00 100,00',
#  'Total                5 100,00 100,00',
#  '',
#  'AREA # 820210132 45889',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5  71,43  71,43',
#  'Rancho                2  28,57 100,00',
#  'Total                7 100,00 100,00',
#  '',
#  'AREA # 820210133 45890',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210134 45891',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1  50,00  50,00',
#  'Casilla                1  50,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 820210201 45892',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210202 45893',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210203 45894',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210204 45895',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210205 45896',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5  55,56  55,56',
#  'Rancho                1  11,11  66,67',
#  'Casilla                3  33,33 100,00',
#  'Total                9 100,00 100,00',
#  '',
#  'AREA # 820210206 45897',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210207 45898',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3  75,00  75,00',
#  'Rancho                1  25,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 820210208 45899',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210209 45900',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210210 45901',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210211 45902',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210212 45903',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               18 100,00 100,00',
#  'Total               18 100,00 100,00',
#  '',
#  'AREA # 820210213 45904',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210214 45905',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210215 45906',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 820210216 45907',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210217 45908',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210218 45909',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 820210301 45910',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3 100,00 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 820210302 45911',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               12  80,00  80,00',
#  'Rancho                2  13,33  93,33',
#  'Local no construido para habitación                1   6,67 100,00',
#  'Total               15 100,00 100,00',
#  '',
#  'AREA # 820210303 45912',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               12 100,00 100,00',
#  'Total               12 100,00 100,00',
#  '',
#  'AREA # 820210304 45913',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 820210305 45914',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210306 45915',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               11 100,00 100,00',
#  'Total               11 100,00 100,00',
#  '',
#  'AREA # 820210307 45916',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210308 45917',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210309 45918',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210310 45919',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               10 100,00 100,00',
#  'Total               10 100,00 100,00',
#  '',
#  'AREA # 820210311 45920',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210312 45921',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210313 45922',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210314 45923',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 820210315 45924',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210316 45925',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5 100,00 100,00',
#  'Total                5 100,00 100,00',
#  '',
#  'AREA # 820210317 45926',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5 100,00 100,00',
#  'Total                5 100,00 100,00',
#  '',
#  'AREA # 820210318 45927',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3  75,00  75,00',
#  'Rancho                1  25,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 820210319 45928',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 820210320 45929',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5 100,00 100,00',
#  'Total                5 100,00 100,00',
#  '',
#  'AREA # 820210321 45930',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 820210322 45931',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 820210323 45932',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B
100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330302 49371',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330303 49372',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3 100,00 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330304 49373',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                4  40,00  40,00',
#  'Rancho                5  50,00  90,00',
#  'Casilla                1  10,00 100,00',
#  'Total               10 100,00 100,00',
#  '',
#  'AREA # 821330305 49374',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3  75,00  75,00',
#  'Rancho                1  25,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 821330306 49375',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330307 49376',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               23  71,88  71,88',
#  'Rancho                3   9,38  81,25',
#  'Casilla                5  15,63  96,88',
#  'Vivienda móvil                1   3,13 100,00',
#  'Total               32 100,00 100,00',
#  '',
#  'AREA # 821330308 49377',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               36  83,72  83,72',
#  'Rancho                5  11,63  95,35',
#  'Vivienda móvil                2   4,65 100,00',
#  'Total               43 100,00 100,00',
#  '',
#  'AREA # 821330309 49378',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               11  78,57  78,57',
#  'Rancho                1   7,14  85,71',
#  'Casilla                2  14,29 100,00',
#  'Total               14 100,00 100,00',
#  '',
#  'AREA # 821330310 49379',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               14  82,35  82,35',
#  'Rancho                2  11,76  94,12',
#  'Casilla                1   5,88 100,00',
#  'Total               17 100,00 100,00',
#  '',
#  'AREA # 821330311 49380',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330312 49381',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2  66,67  66,67',
#  'Rancho                1  33,33 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330313 49382',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casilla                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330314 49383',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               16  84,21  84,21',
#  'Rancho                3  15,79 100,00',
#  'Total               19 100,00 100,00',
#  '',
#  'AREA # 821330315 49384',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                6  66,67  66,67',
#  'Rancho                3  33,33 100,00',
#  'Total                9 100,00 100,00',
#  '',
#  'AREA # 821330316 49385',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330317 49386',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                9  90,00  90,00',
#  'Rancho                1  10,00 100,00',
#  'Total               10 100,00 100,00',
#  '',
#  'AREA # 821330318 49387',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                8  80,00  80,00',
#  'Rancho                2  20,00 100,00',
#  'Total               10 100,00 100,00',
#  '',
#  'AREA # 821330401 49388',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2  40,00  40,00',
#  'Rancho                3  60,00 100,00',
#  'Total                5 100,00 100,00',
#  '',
#  'AREA # 821330402 49389',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2  40,00  40,00',
#  'Rancho                2  40,00  80,00',
#  'Casilla                1  20,00 100,00',
#  'Total                5 100,00 100,00',
#  '',
#  'AREA # 821330403 49390',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1  50,00  50,00',
#  'Casilla                1  50,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330404 49391',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330405 49392',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330406 49393',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330407 49394',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330408 49395',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330409 49396',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330410 49397',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3 100,00 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330411 49398',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330412 49399',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330413 49400',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330414 49401',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330415 49402',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330416 49403',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Vivienda móvil                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330417 49404',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                9 100,00 100,00',
#  'Total                9 100,00 100,00',
#  '',
#  'AREA # 821330501 49405',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               32  88,89  88,89',
#  'Rancho                2   5,56  94,44',
#  'Casilla                2   5,56 100,00',
#  'Total               36 100,00 100,00',
#  '',
#  'AREA # 821330502 49406',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1  33,33  33,33',
#  'Rancho                1  33,33  66,67',
#  'Casilla                1  33,33 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330503 49407',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                6 100,00 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 821330504 49408',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                4  66,67  66,67',
#  'Rancho                2  33,33 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 821330505 49409',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1  33,33  33,33',
#  'Rancho                2  66,67 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330506 49410',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330507 49411',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330508 49412',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2  66,67  66,67',
#  'Rancho                1  33,33 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330509 49413',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                6 100,00 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 821330510 49414',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330511 49415',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               41  75,93  75,93',
#  'Rancho               12  22,22  98,15',
#  'Casilla                1   1,85 100,00',
#  'Total               54 100,00 100,00',
#  '',
#  'AREA # 821330512 49416',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                9  90,00  90,00',
#  'Casilla                1  10,00 100,00',
#  'Total               10 100,00 100,00',
#  '',
#  'AREA # 821330513 49417',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5  83,33  83,33',
#  'Casilla                1  16,67 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 821330514 49418',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Rancho                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330515 49419',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                4 100,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 821330516 49420',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Rancho                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330517 49421',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5  71,43  71,43',
#  'Rancho                1  14,29  85,71',
#  'Casilla                1  14,29 100,00',
#  'Total                7 100,00 100,00',
#  '',
#  'AREA # 821330518 49422',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330519 49423',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330520 49424',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330521 49425',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330522 49426',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2  66,67  66,67',
#  'Rancho                1  33,33 100,00',
#  'Total                3 100,00 100,00',
#  '',
#  'AREA # 821330523 49427',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                3  50,00  50,00',
#  'Rancho                3  50,00 100,00',
#  'Total                6 100,00 100,00',
#  '',
#  'AREA # 821330524 49428',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               31  91,18  91,18',
#  'Rancho                2   5,88  97,06',
#  'Casilla                1   2,94 100,00',
#  'Total               34 100,00 100,00',
#  '',
#  'AREA # 821330525 49429',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B               20  95,24  95,24',
#  'Rancho                1   4,76 100,00',
#  'Total               21 100,00 100,00',
#  '',
#  'AREA # 821330526 49430',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2  50,00  50,00',
#  'Rancho                2  50,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 821330527 49431',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Rancho                1  50,00  50,00',
#  'Casilla                1  50,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330528 49432',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                5 100,00 100,00',
#  'Total                5 100,00 100,00',
#  '',
#  'AREA # 821330529 49433',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330530 49434',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330531 49435',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                7  87,50  87,50',
#  'Rancho                1  12,50 100,00',
#  'Total                8 100,00 100,00',
#  '',
#  'AREA # 821330532 49436',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2  50,00  50,00',
#  'Rancho                2  50,00 100,00',
#  'Total                4 100,00 100,00',
#  '',
#  'AREA # 821330533 49437',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330534 49438',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330601 49439',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330602 49440',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330603 49441',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Rancho                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330604 49442',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330605 49443',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330606 49444',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330607 49445',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330608 49446',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1  50,00  50,00',
#  'Rancho                1  50,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330609 49447',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330610 49448',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330611 49449',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330612 49450',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330613 49451',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330614 49452',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330615 49453',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330616 49454',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330617 49455',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                7  77,78  77,78',
#  'Rancho                2  22,22 100,00',
#  'Total                9 100,00 100,00',
#  '',
#  'AREA # 821330618 49456',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330619 49457',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330620 49458',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330621 49459',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330622 49460',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00',
#  '',
#  'AREA # 821330623 49461',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330624 49462',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330625 49463',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330626 49464',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330627 49465',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330628 49466',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330629 49467',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                2 100,00 100,00',
#  'Total                2 100,00 100,00',
#  '',
#  'AREA # 821330630 49468',
#  '',
#  'Tabla vacía',
#  '',
#  '',
#  'AREA # 821330631 49469',
#  '',
#  'Tipo de vivienda Casos % Acumulado %',
#  'Casa Tipo B                1 100,00 100,00',
#  'Total                1 100,00 100,00']

# %%
import pandas as pd
df_data = {
    'radio_cens': [],
    'tipo_vivienda': [],
    'casos': []
}

radio_censal = None
for r in data_por_radio_censal:
    if not len(r):
        continue
    cells = [i for i in r.split('  ') if len(i)]
    key = cells[0]
    if 'AREA #' in key:
        radio_censal = int(r.replace('AREA # ', '').split(' ')[0])
        continue
    elif key == 'Tabla vacía':
        df_data['radio_cens'].append(radio_censal)
        df_data['tipo_vivienda'].append('Total')
        df_data['casos'].append(0)
        
    elif len(cells) > 1:
        resultados = cells[1].strip().split(' ')
        try:
            casos = int(resultados[0])
        except ValueError:
            continue
        df_data['radio_cens'].append(radio_censal)
        df_data['tipo_vivienda'].append(key)
        df_data['casos'].append(casos)
    else:
        continue
df = pd.DataFrame(columns=df_data.keys(), data=df_data)

for rc in df.radio_cens.unique():
    resultados = df.loc[df.radio_cens == rc]
    for tv in df.tipo_vivienda.unique():
        if tv in resultados.tipo_vivienda.unique():
            continue
        df_data['radio_cens'].append(rc)
        df_data['tipo_vivienda'].append(tv)
        df_data['casos'].append(0)
        
df = pd.DataFrame(columns=df_data.keys(), data=df_data)
df.pivot_table('casos', ['radio_cens'], 'tipo_vivienda')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4536f4354d2c> in <module>()
#       7
#       8 radio_censal = None
# ----> 9 for r in data_por_radio_censal:
#      10     if not len(r):
#      11         continue
#
# NameError: name 'data_por_radio_censal' is not defined

# %%
def soup_to_dataframe(soup):
    df_data = {
        'radio_cens': [],
        'tipo_vivienda': [],
        'casos': []
    }
    rows = soup.find('table').find_all('tr')
    rows_with_data = [r.text.replace('\n', ' ').strip() for r in rows][13:-5]
    resumen = rows_with_data[-10:]
    data_por_radio_censal = rows_with_data[:-13] 

    radio_censal = None
    for r in data_por_radio_censal:
        if not len(r):
            continue
        cells = [i for i in r.split('  ') if len(i)]
        key = cells[0]
        if 'AREA #' in key:
            radio_censal = int(r.replace('AREA # ', '').split(' ')[0])
            continue
        elif key == 'Tabla vacía':
            df_data['radio_cens'].append(radio_censal)
            df_data['tipo_vivienda'].append('Total')
            df_data['casos'].append(0)

        elif len(cells) > 1:
            resultados = cells[1].strip().split(' ')
            try:
                casos = int(resultados[0])
            except ValueError:
                continue
            df_data['radio_cens'].append(radio_censal)
            df_data['tipo_vivienda'].append(key)
            df_data['casos'].append(casos)
        else:
            continue
    df = pd.DataFrame(columns=df_data.keys(), data=df_data)

    for rc in df.radio_cens.unique():
        resultados = df.loc[df.radio_cens == rc]
        for tv in df.tipo_vivienda.unique():
            if tv in resultados.tipo_vivienda.unique():
                continue
            df_data['radio_cens'].append(rc)
            df_data['tipo_vivienda'].append(tv)
            df_data['casos'].append(0)

    df = pd.DataFrame(columns=df_data.keys(), data=df_data)
    return df.pivot_table('casos', ['radio_cens'], 'tipo_vivienda')

# %%
df = soup_to_dataframe(soup_i)

# %%
df
# Out:
# tipo_vivienda  Casa Tipo B  Casilla  Departamento  \
# radio_cens
